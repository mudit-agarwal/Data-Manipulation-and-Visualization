# %%
import pandas as pd

iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")

# %% [markdown]
# #### 1) We can read any type of file in Pandas like this
#
# pd.read_csv
#
# pd.read_excel
#
# pd.read_sas

# %% [markdown]
# #### 2) First copy the dataSet into another varaible to preserve the original

# %%
df = iris.copy()

# %% [markdown]
# #### 3) To change the columns we can do the below

# %%
df.columns = ['sl','sw','pl','pw','flower_type']

# %% [markdown]
# #### 4) See Head, Shape  and data types and describe

# %%
df.head()
# Out:
#     sl   sw   pl   pw  flower_type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# Note : If we do df.head(3), it will show three records. By default is

# %%
df.shape
# Out:
# (149, 5)

# %%
df.dtypes
# Out:
# sl             float64
# sw             float64
# pl             float64
# pw             float64
# flower_type     object
# dtype: object

# %%
df.describe()
# Out:
#                sl          sw          pl          pw
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# Note : pd.describe() is AMAZINGGGGG

# %% [markdown]
# We can get count, min, max  of a coulmn etc.
#
# If there is NaN value or blanks, the count will change
#
# 25% means 25 percentile - How much you should get to be higher than 25% of the candidates

# %% [markdown]
# #### 5) Now we will see how to access a particluar column or particular row

# %% [markdown]
# df.column_name gives us the column
#
# df.columns gives us columns ["use the word "Columns"]

# %%
df.columns
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'flower_type'], dtype='object')

# %%
df.sl
# Out:
# 0      4.9
# 1      4.7
# 2      4.6
# 3      5.0
# 4      5.4
# 5      4.6
# 6      5.0
# 7      4.4
# 8      4.9
# 9      5.4
# 10     4.8
# 11     4.8
# 12     4.3
# 13     5.8
# 14     5.7
# 15     5.4
# 16     5.1
# 17     5.7
# 18     5.1
# 19     5.4
# 20     5.1
# 21     4.6
# 22     5.1
# 23     4.8
# 24     5.0
# 25     5.0
# 26     5.2
# 27     5.2
# 28     4.7
# 29     4.8
#       ...
# 119    6.9
# 120    5.6
# 121    7.7
# 122    6.3
# 123    6.7
# 124    7.2
# 125    6.2
# 126    6.1
# 127    6.4
# 128    7.2
# 129    7.4
# 130    7.9
# 131    6.4
# 132    6.3
# 133    6.1
# 134    7.7
# 135    6.3
# 136    6.4
# 137    6.0
# 138    6.9
# 139    6.7
# 140    6.9
# 141    5.8
# 142    6.8
# 143    6.7
# 144    6.7
# 145    6.3
# 146    6.5
# 147    6.2
# 148    5.9
# Name: sl, Length: 149, dtype: float64

# %% [markdown]
# #### IMP : 6) To access particular rows and elements

# %%
df.iloc[1:4,:]
# Out:
#     sl   sw   pl   pw  flower_type
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# #### 7) Accesing Null Values

# %%
df.isnull().sum()
# Out:
# sl             0
# sw             0
# pl             0
# pw             0
# flower_type    0
# dtype: int64

# %% [markdown]
# #### 8) Comparing values

# %%
df.sl > 5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12     False
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21     False
# 22      True
# 23     False
# 24     False
# 25     False
# 26      True
# 27      True
# 28     False
# 29     False
#        ...
# 119     True
# 120     True
# 121     True
# 122     True
# 123     True
# 124     True
# 125     True
# 126     True
# 127     True
# 128     True
# 129     True
# 130     True
# 131     True
# 132     True
# 133     True
# 134     True
# 135     True
# 136     True
# 137     True
# 138     True
# 139     True
# 140     True
# 141     True
# 142     True
# 143     True
# 144     True
# 145     True
# 146     True
# 147     True
# 148     True
# Name: sl, Length: 149, dtype: bool

# %%
df[df.sl > 5]
#Only gives those rows for which data is correct
# Out:
#       sl   sw   pl   pw      flower_type
# 4    5.4  3.9  1.7  0.4      Iris-setosa
# 9    5.4  3.7  1.5  0.2      Iris-setosa
# 13   5.8  4.0  1.2  0.2      Iris-setosa
# 14   5.7  4.4  1.5  0.4      Iris-setosa
# 15   5.4  3.9  1.3  0.4      Iris-setosa
# 16   5.1  3.5  1.4  0.3      Iris-setosa
# 17   5.7  3.8  1.7  0.3      Iris-setosa
# 18   5.1  3.8  1.5  0.3      Iris-setosa
# 19   5.4  3.4  1.7  0.2      Iris-setosa
# 20   5.1  3.7  1.5  0.4      Iris-setosa
# 22   5.1  3.3  1.7  0.5      Iris-setosa
# 26   5.2  3.5  1.5  0.2      Iris-setosa
# 27   5.2  3.4  1.4  0.2      Iris-setosa
# 30   5.4  3.4  1.5  0.4      Iris-setosa
# 31   5.2  4.1  1.5  0.1      Iris-setosa
# 32   5.5  4.2  1.4  0.2      Iris-setosa
# 35   5.5  3.5  1.3  0.2      Iris-setosa
# 38   5.1  3.4  1.5  0.2      Iris-setosa
# 43   5.1  3.8  1.9  0.4      Iris-setosa
# 45   5.1  3.8  1.6  0.2      Iris-setosa
# 47   5.3  3.7  1.5  0.2      Iris-setosa
# 49   7.0  3.2  4.7  1.4  Iris-versicolor
# ...

# %%
df[df.flower_type =='Iris-virginica']
# Out:
#       sl   sw   pl   pw     flower_type
# 99   6.3  3.3  6.0  2.5  Iris-virginica
# 100  5.8  2.7  5.1  1.9  Iris-virginica
# 101  7.1  3.0  5.9  2.1  Iris-virginica
# 102  6.3  2.9  5.6  1.8  Iris-virginica
# 103  6.5  3.0  5.8  2.2  Iris-virginica
# 104  7.6  3.0  6.6  2.1  Iris-virginica
# 105  4.9  2.5  4.5  1.7  Iris-virginica
# 106  7.3  2.9  6.3  1.8  Iris-virginica
# 107  6.7  2.5  5.8  1.8  Iris-virginica
# 108  7.2  3.6  6.1  2.5  Iris-virginica
# 109  6.5  3.2  5.1  2.0  Iris-virginica
# 110  6.4  2.7  5.3  1.9  Iris-virginica
# 111  6.8  3.0  5.5  2.1  Iris-virginica
# 112  5.7  2.5  5.0  2.0  Iris-virginica
# 113  5.8  2.8  5.1  2.4  Iris-virginica
# 114  6.4  3.2  5.3  2.3  Iris-virginica
# 115  6.5  3.0  5.5  1.8  Iris-virginica
# 116  7.7  3.8  6.7  2.2  Iris-virginica
# 117  7.7  2.6  6.9  2.3  Iris-virginica
# 118  6.0  2.2  5.0  1.5  Iris-virginica
# 119  6.9  3.2  5.7  2.3  Iris-virginica
# 120  5.6  2.8  4.9  2.0  Iris-virginica
# ...

# %% [markdown]
# #### 9) Creating a new Column

# %%
df["New_Column"] = df["sl"]- df["pl"]
df.head()
# Out:
#     sl   sw   pl   pw  flower_type  New_Column
# 0  4.9  3.0  1.4  0.2  Iris-setosa         3.5
# 1  4.7  3.2  1.3  0.2  Iris-setosa         3.4
# 2  4.6  3.1  1.5  0.2  Iris-setosa         3.1
# 3  5.0  3.6  1.4  0.2  Iris-setosa         3.6
# 4  5.4  3.9  1.7  0.4  Iris-setosa         3.7

# %% [markdown]
# #### 10) Groupby of 1 type of objects in a coulmn

# %%
for i in df["flower_type"].value_counts():
    print(i,end=" ")
# Out:
# 50 50 49
